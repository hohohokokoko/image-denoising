# %%
import os
from PIL import Image
import numpy as np

from skimage import img_as_float
from skimage.restoration import denoise_nl_means, estimate_sigma
from skimage.metrics import peak_signal_noise_ratio, structural_similarity
from skimage.util import random_noise

# %%
set = "./CBSD/"
sigmas = [0.1]

psnr_result = {}
ssim_result = {}

for sigma in sigmas:
    print(sigma)

    psnrs = []
    ssims = []

    for img_name in os.listdir(set):
        print(img_name)

        img = Image.open(set + img_name)
        img_arr = np.asarray(img)
        img_arr = img_as_float(img_arr)

        noisy = random_noise(img_arr, mode='gaussian', var=sigma**2)

        # estimate the noise standard deviation from the noisy image
        sigma_est = np.mean(estimate_sigma(noisy, channel_axis=-1))
        print(f'estimated noise standard deviation = {sigma_est}')

        # slow algorithm
        denoise = denoise_nl_means(noisy, sigma=sigma_est, fast_mode=False, channel_axis=-1)

        psnr = peak_signal_noise_ratio(img_arr, denoise, data_range=denoise.max() - denoise.min())
        print("PSNR:", psnr)
        psnrs.append(psnr)

        ssim = structural_similarity(img_arr, denoise, data_range=denoise.max() - denoise.min(), channel_axis=-1)
        print("SSIM:", ssim)
        ssims.append(ssim)

        print()

    psnr_result[sigma] = psnrs
    ssim_result[sigma] = ssims
# Out:
# 0.1
# 0033.png
# estimated noise standard deviation = 0.10758242008011866
# PSNR: 23.00265704733029
# SSIM: 0.6887824687168197
#
# 0021.png
# estimated noise standard deviation = 0.09967848679541014
# PSNR: 25.45191960840313
# SSIM: 0.6876759141910652
#
# 0061.png
# estimated noise standard deviation = 0.10042401296461746
# PSNR: 27.291758507827772
# SSIM: 0.6797250295287142
#
# 0030.png
# estimated noise standard deviation = 0.09724244156966615
# PSNR: 27.42320578077216
# SSIM: 0.8531557969712721
#
# 0036.png
# estimated noise standard deviation = 0.10117867654881442
# PSNR: 23.861175434262005
# SSIM: 0.6957710588117342
#
# 0045.png
# estimated noise standard deviation = 0.09477397019934126
# PSNR: 28.175885835080145
# SSIM: 0.80330310115089
#
# 0031.png
# estimated noise standard deviation = 0.09434812123070502
# PSNR: 25.591473609512178
# SSIM: 0.6773174520106672
#
# 0058.png
# estimated noise standard deviation = 0.09937997362651696
# PSNR: 26.258970439609442
# SSIM: 0.7141714842334165
#
# 0048.png
# estimated noise standard deviation = 0.10137985475821588
# PSNR: 24.635568621175995
# SSIM: 0.6726666216363033
#
# 0029.png
# estimated noise standard deviation = 0.08836360313854058
# PSNR: 26.43665255230323
# SSIM: 0.7572267461802418
#
# 0019.png
# estimated noise standard deviation = 0.09946094605878679
# PSNR: 26.647467656528647
# SSIM: 0.7119896079625853
#
# 0026.png
# estimated noise standard deviation = 0.09628185654318837
# PSNR: 24.64635652551025
# SSIM: 0.777559539608147
#
# 0053.png
# estimated noise standard deviation = 0.08644955376709278
# PSNR: 27.166341924105105
# SSIM: 0.7241253383861829
#
# 0014.png
# estimated noise standard deviation = 0.09909776175122599
# PSNR: 26.507414812105196
# SSIM: 0.7107667994279394
#
# 0000.png
# estimated noise standard deviation = 0.098552856075961
# PSNR: 32.12054583314154
# SSIM: 0.8916641102878526
#
# 0013.png
# estimated noise standard deviation = 0.08912892978279989
# PSNR: 28.24063449489155
# SSIM: 0.8166151371580183
#
# 0020.png
# estimated noise standard deviation = 0.09802625867910002
# PSNR: 28.521011280683553
# SSIM: 0.7868201129818386
#
# 0028.png
# estimated noise standard deviation = 0.099565098170476
# PSNR: 26.6150318578558
# SSIM: 0.7660717831039987
#
# 0039.png
# estimated noise standard deviation = 0.10392288594661864
# PSNR: 24.583005903677662
# SSIM: 0.3739207902625638
#
# 0054.png
# estimated noise standard deviation = 0.09896561914588857
# PSNR: 28.425595168516118
# SSIM: 0.6604359043297773
#
# 0057.png
# estimated noise standard deviation = 0.11089692435657884
# PSNR: 21.965339361127615
# SSIM: 0.592379465888234
#
# 0005.png
# estimated noise standard deviation = 0.09628243653723641
# PSNR: 27.609700155222438
# SSIM: 0.7234256829469429
#
# 0051.png
# estimated noise standard deviation = 0.09410353481548046
# PSNR: 24.99687752433312
# SSIM: 0.6738935647885049
#
# 0006.png
# estimated noise standard deviation = 0.08943369638767369
# PSNR: 26.974960053113286
# SSIM: 0.8395162828473005
#
# 0010.png
# estimated noise standard deviation = 0.09491598275343345
# PSNR: 28.087350048996854
# SSIM: 0.8125628249795341
#
# 0035.png
# estimated noise standard deviation = 0.10991239818827958
# PSNR: 22.059957021195565
# SSIM: 0.6511498229235341
#
# 0027.png
# estimated noise standard deviation = 0.09318967348582667
# PSNR: 24.805901320781153
# SSIM: 0.6768472011044646
#
# 0008.png
# estimated noise standard deviation = 0.10050242720074463
# PSNR: 24.028987175464707
# SSIM: 0.604116994635541
#
# 0062.png
# estimated noise standard deviation = 0.0978155060893469
# PSNR: 28.29904496593672
# SSIM: 0.7309639122441854
#
# 0065.png
# estimated noise standard deviation = 0.10216049045383734
# PSNR: 25.03842223777304
# SSIM: 0.6029373844039508
#
# 0067.png
# estimated noise standard deviation = 0.08562105479214159
# PSNR: 24.12646275447498
# SSIM: 0.763949538428636
#
# 0022.png
# estimated noise standard deviation = 0.10014995499568073
# PSNR: 26.06583022273874
# SSIM: 0.7822378305605758
#
# 0009.png
# estimated noise standard deviation = 0.08254552998756458
# PSNR: 27.197103659538577
# SSIM: 0.8071869550526513
#
# 0012.png
# estimated noise standard deviation = 0.08736940520742535
# PSNR: 24.671517254075454
# SSIM: 0.7131243238744402
#
# 0066.png
# estimated noise standard deviation = 0.08590066500583521
# PSNR: 26.5253040292197
# SSIM: 0.6945622045955787
#
# 0032.png
# estimated noise standard deviation = 0.06708876860437678
# PSNR: 28.420606016226717
# SSIM: 0.7993379264737412
#
# 0043.png
# estimated noise standard deviation = 0.09232533046287493
# PSNR: 25.882187504078157
# SSIM: 0.6968927447555223
#
# 0007.png
# estimated noise standard deviation = 0.10558270456196682
# PSNR: 23.254063099042405
# SSIM: 0.7679516657367166
#
# 0002.png
# estimated noise standard deviation = 0.08899234444081584
# PSNR: 29.661207234343316
# SSIM: 0.773187734467821
#
# 0017.png
# estimated noise standard deviation = 0.10077350649790362
# PSNR: 26.282469482013255
# SSIM: 0.7073882733299316
#
# 0023.png
# estimated noise standard deviation = 0.09666324463315058
# PSNR: 29.652740758085848
# SSIM: 0.8181251882132975
#
# 0011.png
# estimated noise standard deviation = 0.09918430011202743
# PSNR: 27.380903104240254
# SSIM: 0.7479551651830905
#
# 0040.png
# estimated noise standard deviation = 0.09900347360559454
# PSNR: 26.874129195711806
# SSIM: 0.6702516219615114
#
# 0034.png
# estimated noise standard deviation = 0.09974047030939236
# PSNR: 27.42088395804408
# SSIM: 0.685882437062729
#
# 0037.png
# estimated noise standard deviation = 0.09920598478988178
# PSNR: 26.106293612760997
# SSIM: 0.8297571167909951
#
# 0025.png
# estimated noise standard deviation = 0.0937254269276024
# PSNR: 27.162030010239544
# SSIM: 0.7642674511190926
#
# 0044.png
# estimated noise standard deviation = 0.09943172686328687
# PSNR: 27.9901657896529
# SSIM: 0.7454990878106101
#
# 0055.png
# estimated noise standard deviation = 0.09719621333294913
# PSNR: 26.346935179294245
# SSIM: 0.7295656228560272
#
# 0046.png
# estimated noise standard deviation = 0.1032443214025011
# PSNR: 25.18818634992519
# SSIM: 0.714561928108405
#
# 0064.png
# estimated noise standard deviation = 0.09981009722056912
# PSNR: 24.503717933709087
# SSIM: 0.6993855492980791
#
# 0004.png
# estimated noise standard deviation = 0.09935592466001818
# PSNR: 26.424681362326396
# SSIM: 0.7094442748560591
#
# 0041.png
# estimated noise standard deviation = 0.09750880390492378
# PSNR: 26.048580920392524
# SSIM: 0.6464962701517322
#
# 0016.png
# estimated noise standard deviation = 0.09533190200715137
# PSNR: 27.0791318992857
# SSIM: 0.7498962766229823
#
# 0049.png
# estimated noise standard deviation = 0.10371117674501114
# PSNR: 23.91528430523904
# SSIM: 0.6552368217814807
#
# 0001.png
# estimated noise standard deviation = 0.0992203140081352
# PSNR: 25.163897981406144
# SSIM: 0.6674067169109413
#
# 0056.png
# estimated noise standard deviation = 0.09985152279817422
# PSNR: 25.57433079459489
# SSIM: 0.6745395244174271
#
# 0060.png
# estimated noise standard deviation = 0.09948099538968147
# PSNR: 28.19947061029346
# SSIM: 0.7044114885363862
#
# 0015.png
# estimated noise standard deviation = 0.10215266405769986
# PSNR: 24.492141664090298
# SSIM: 0.6142809848542713
#
# 0052.png
# estimated noise standard deviation = 0.102997563316231
# PSNR: 26.611746934574217
# SSIM: 0.7216024457178931
#
# 0042.png
# estimated noise standard deviation = 0.09849282378580172
# PSNR: 29.443877870107997
# SSIM: 0.8323477838523198
#
# 0003.png
# estimated noise standard deviation = 0.09810810089396262
# PSNR: 25.672838513795057
# SSIM: 0.6864082137621299
#
# 0018.png
# estimated noise standard deviation = 0.09428581921218909
# PSNR: 26.12371636920581
# SSIM: 0.7611494751209982
#
# 0024.png
# estimated noise standard deviation = 0.09503078137854593
# PSNR: 26.400922273402507
# SSIM: 0.6946973892795002
#
# 0050.png
# estimated noise standard deviation = 0.08729018857871917
# PSNR: 28.546648990084176
# SSIM: 0.7559766227898482
#
# 0059.png
# estimated noise standard deviation = 0.10016972780939433
# PSNR: 25.444423326530785
# SSIM: 0.6113574503124234
#
# 0038.png
# estimated noise standard deviation = 0.09207407501422916
# PSNR: 30.85670299526223
# SSIM: 0.8248291799165236
#
# 0047.png
# estimated noise standard deviation = 0.09964534028147604
# PSNR: 26.44165816397217
# SSIM: 0.7058337293987709
#
# 0063.png
# estimated noise standard deviation = 0.07930443271893957
# PSNR: 30.375089344884515
# SSIM: 0.8540195187442196

# %%
print(psnr_result)
print(ssim_result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 print(psnr_result)
#       2 print(ssim_result)
#
# NameError: name 'psnr_result' is not defined
